# %%
import tensorflow as tf
import os
import numpy as np
import re
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# F:\Anaconda3\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
lines = tf.gfile.GFile('output_labels.txt').readlines()
uid_to_human = {}

# 一行一行读取数据
for uid,line in enumerate(lines) :
    #去掉换行符
    line=line.strip('\n')
    uid_to_human[uid] = line

# 分类编号变成描述
def id_to_string(node_id):
    if node_id not in uid_to_human:
        return ''
    return uid_to_human[node_id]


# 创建一个图来存放训练好的模型
with tf.gfile.GFile('output_graph.pb', 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    tf.import_graph_def(graph_def, name='')


with tf.Session() as sess:
    # final_result为输出tensor的名字
    softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')
    # 遍历目录
    for root,dirs,files in os.walk('images/'):
        for file in files:
            # 载入图片
            image_data = tf.gfile.GFile(os.path.join(root,file), 'rb').read()
            # 把图像数据传入模型获得模型输出结果
            predictions = sess.run(softmax_tensor,{'DecodeJpeg/contents:0': image_data})
            # 把结果转为1维数据
            predictions = np.squeeze(predictions)
            # 打印图片路径及名称
            image_path = os.path.join(root,file)
            print(image_path)
            # 显示图片
            img=Image.open(image_path)
            plt.imshow(img)
            plt.axis('off')
            plt.show()

            # 排序
            top_k = predictions.argsort()[::-1]
            for node_id in top_k:     
                # 获取分类名称
                human_string = id_to_string(node_id)
                # 获取该分类的置信度
                score = predictions[node_id]
                print('%s (score = %.5f)' % (human_string, score))
            print()
# Out:
# images/停机坪.jpg
# 1.停机坪 (score = 0.89034)
# 2.机舱 (score = 0.02382)
# 3.游乐场 (score = 0.01648)
# 0.航站楼 (score = 0.01507)
# 6.艺术室 (score = 0.01091)
# 5.舞台 (score = 0.01073)
# 4.冰场 (score = 0.01000)
# 7.流水线 (score = 0.00961)
# 9.橄榄球场 (score = 0.00812)
# 8.棒球场 (score = 0.00492)
#
# images/冰场.jpg
# 4.冰场 (score = 0.80866)
# 0.航站楼 (score = 0.03819)
# 3.游乐场 (score = 0.03303)
# 6.艺术室 (score = 0.02212)
# 7.流水线 (score = 0.02101)
# 1.停机坪 (score = 0.02081)
# 8.棒球场 (score = 0.01998)
# 5.舞台 (score = 0.01557)
# 9.橄榄球场 (score = 0.01371)
# 2.机舱 (score = 0.00692)
#
# images/机舱.jpg
# 2.机舱 (score = 0.46424)
# 6.艺术室 (score = 0.16963)
# 3.游乐场 (score = 0.07234)
# 7.流水线 (score = 0.07230)
# 0.航站楼 (score = 0.06094)
# 5.舞台 (score = 0.05537)
# 1.停机坪 (score = 0.04015)
# 4.冰场 (score = 0.03409)
# 9.橄榄球场 (score = 0.01856)
# 8.棒球场 (score = 0.01238)
#
# images/棒球场.jpg
# 8.棒球场 (score = 0.59752)
# 9.橄榄球场 (score = 0.15840)
# 4.冰场 (score = 0.08294)
# 5.舞台 (score = 0.03443)
# 3.游乐场 (score = 0.02808)
# 7.流水线 (score = 0.02716)
# 0.航站楼 (score = 0.02440)
# 6.艺术室 (score = 0.02081)
# 1.停机坪 (score = 0.01578)
# 2.机舱 (score = 0.01049)
#
# images/橄榄球场.jpg
# 9.橄榄球场 (score = 0.90586)
# 8.棒球场 (score = 0.02925)
# 4.冰场 (score = 0.01253)
# 3.游乐场 (score = 0.01040)
# 1.停机坪 (score = 0.00850)
# 2.机舱 (score = 0.00726)
# 6.艺术室 (score = 0.00722)
# 0.航站楼 (score = 0.00672)
# 7.流水线 (score = 0.00647)
# 5.舞台 (score = 0.00579)
#
# images/流水线.jpg
# 7.流水线 (score = 0.69390)
# 6.艺术室 (score = 0.17190)
# 0.航站楼 (score = 0.04776)
# 3.游乐场 (score = 0.02924)
# 5.舞台 (score = 0.01459)
# 4.冰场 (score = 0.01100)
# 2.机舱 (score = 0.01012)
# 8.棒球场 (score = 0.00897)
# 1.停机坪 (score = 0.00838)
# 9.橄榄球场 (score = 0.00414)
#
# images/游乐场.jpg
# 3.游乐场 (score = 0.79626)
# 4.冰场 (score = 0.03628)
# 6.艺术室 (score = 0.03058)
# 5.舞台 (score = 0.02489)
# 0.航站楼 (score = 0.02378)
# 7.流水线 (score = 0.02374)
# 1.停机坪 (score = 0.01775)
# 9.橄榄球场 (score = 0.01698)
# 8.棒球场 (score = 0.01647)
# 2.机舱 (score = 0.01326)
#
# images/舞台.jpg
# 6.艺术室 (score = 0.21044)
# 3.游乐场 (score = 0.20140)
# 5.舞台 (score = 0.18307)
# 7.流水线 (score = 0.11354)
# 9.橄榄球场 (score = 0.07624)
# 4.冰场 (score = 0.05672)
# 0.航站楼 (score = 0.05430)
# 8.棒球场 (score = 0.04579)
# 2.机舱 (score = 0.03441)
# 1.停机坪 (score = 0.02409)
#
# images/航站楼.jpg
# 0.航站楼 (score = 0.79049)
# 7.流水线 (score = 0.06237)
# 4.冰场 (score = 0.05007)
# 5.舞台 (score = 0.03692)
# 2.机舱 (score = 0.01724)
# 6.艺术室 (score = 0.01499)
# 3.游乐场 (score = 0.01340)
# 8.棒球场 (score = 0.00979)
# 1.停机坪 (score = 0.00286)
# 9.橄榄球场 (score = 0.00187)
#
# images/艺术室.jpg
# 6.艺术室 (score = 0.39544)
# 3.游乐场 (score = 0.30043)
# 5.舞台 (score = 0.07979)
# 0.航站楼 (score = 0.04966)
# 7.流水线 (score = 0.03982)
# 4.冰场 (score = 0.03814)
# 8.棒球场 (score = 0.02632)
# 1.停机坪 (score = 0.02513)
# 9.橄榄球场 (score = 0.02425)
# 2.机舱 (score = 0.02103)
